# %%
import pandas as pd

# %%
df = pd.read_csv("saccade_data.tsv", sep="\t")
df.tail()
# Out:
#        Recording timestamp  Computer timestamp       Sensor Project name  \
# 25603            101270352          7647883560  Eye Tracker  Gaze_model1
# 25604            101278727          7647891935  Eye Tracker  Gaze_model1
# 25605            101287015          7647900223  Eye Tracker  Gaze_model1
# 25606            101306156          7647919364          NaN  Gaze_model1
# 25607            101450654          7648063862          NaN  Gaze_model1
#
#       Participant name Recording name  Recording duration Timeline name  \
# 25603           Sergiy     Recording2              101451     Timeline1
# 25604           Sergiy     Recording2              101451     Timeline1
# 25605           Sergiy     Recording2              101451     Timeline1
# 25606           Sergiy     Recording2              101451     Timeline1
# 25607           Sergiy     Recording2              101451     Timeline1
#
#       Recording Fixation filter name Recording software version  ...  \
# ...

# %% [markdown]
# Clean up data (Columns ect.) Skriver df.columns og får opp alle kolonnene.

# %%
df.columns
# Out:
# Index(['Recording timestamp', 'Computer timestamp', 'Sensor', 'Project name',
#        'Participant name', 'Recording name', 'Recording duration',
#        'Timeline name', 'Recording Fixation filter name',
#        'Recording software version', 'Recording resolution height',
#        'Recording resolution width', 'Recording monitor latency',
#        'Average calibration accuracy (mm)',
#        'Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration accuracy (degrees)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration accuracy (pixels)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)',
#        'Average validation accuracy (mm)',
#        'Average validation precision SD (mm)',
#        'Average validation precision RMS (mm)',
# ...

# %%
cols_to_keep= ['Recording timestamp', "Participant name", "Recording name", "Eye movement type", "Gaze event duration", "Fixation point X (MCSnorm)", "Fixation point Y (MCSnorm)", "Presented Media name", "Eye movement type index"]

# %%
df = df[cols_to_keep]

# %%
df.tail()
# Out:
#     Recording timestamp Participant name Recording name Eye movement type  \
# 0                     0            Eskil     Recording1               NaN
# 1                 89664            Eskil     Recording1               NaN
# 2                105636            Eskil     Recording1               NaN
# 3                121622            Eskil     Recording1               NaN
# 4                137575            Eskil     Recording1      EyesNotFound
# 5                138045            Eskil     Recording1      EyesNotFound
# 6                146339            Eskil     Recording1      Unclassified
# 7                153613            Eskil     Recording1      Unclassified
# 8                154676            Eskil     Recording1      Unclassified
# 9                162967            Eskil     Recording1      EyesNotFound
# 10               169589            Eskil     Recording1      Unclassified
# 11               171379            Eskil     Recording1      Unclassified
# ...

# %% [markdown]
# Filtrerer, ved å legge inn boolsk condition i df[], og får true-radene. Filtrer bort kalibrering.

# %%
df =  df[df['Presented Media name']=="test1.png"]
df = df[df["Eye movement type"]=="Saccade"]

# %%
df.tail()
# Out:
#        Recording timestamp Participant name Recording name Eye movement type  \
# 25564            100945398           Sergiy     Recording2           Saccade
# 25566            100962090           Sergiy     Recording2           Saccade
# 25567            100970403           Sergiy     Recording2           Saccade
# 25596            101212023           Sergiy     Recording2           Saccade
# 25597            101220355           Sergiy     Recording2           Saccade
#
#        Gaze event duration Fixation point X (MCSnorm)  \
# 25564                 17.0                        NaN
# 25566                 17.0                        NaN
# 25567                 17.0                        NaN
# 25596                 17.0                        NaN
# 25597                 17.0                        NaN
#
#       Fixation point Y (MCSnorm) Presented Media name  Eye movement type index
# 25564                        NaN            test1.png                    266.0
# ...

# %% [markdown]
# Videre deler vi opp i alle deltakerne.

# %%
uniqueValues = df["Participant name"].unique()

print(uniqueValues)

DF_list = list()

for name in uniqueValues: 
    df_names = df[df["Participant name"] == name]
    DF_list.append(df_names)
    
print(len(DF_list))
# Out:
# ['Eskil' 'Sergiy']
# 2

# %% [markdown]
# Alle fixations rett etter hverandre med lik verdi, og likt fokuseringspunkt, må slås sammen

# %%
for x in range(len(DF_list)):
    DF_list[x].drop_duplicates(subset="Eye movement type index", inplace = True)
# Out:
# c:\users\julie solvin jacobse\pycharmprojects\ktn\venv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DF_list[0].head(20)
# Out:
#     Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                     0          7386674582          NaN  Gaze_model1
# 4                137575          7386812157        Mouse  Gaze_model1
# 9                162967          7386837549  Eye Tracker  Gaze_model1
# 13               185574          7386860156        Mouse  Gaze_model1
# 18               212957          7386887539  Eye Tracker  Gaze_model1
# 23               237961          7386912543  Eye Tracker  Gaze_model1
# 27               263005          7386937587  Eye Tracker  Gaze_model1
# 32               288022          7386962604  Eye Tracker  Gaze_model1
# 36               313017          7386987599  Eye Tracker  Gaze_model1
# 40               337679          7387012261        Mouse  Gaze_model1
# 44               361612          7387036194        Mouse  Gaze_model1
# 49               388079          7387062661  Eye Tracker  Gaze_model1
# ...

# %% [markdown]
# Spørsmål:
